# %% [markdown]
# ## 1. Setup and Imports

# %%
import duckdb
import pandas as pd
import numpy as np
import plotly.graph_objects as go
import plotly.express as px
from pathlib import Path

# Display settings
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', 50)

print("✓ Imports complete")
# Out:
# ✓ Imports complete

# %% [markdown]
# ## 2. Connect to Databases

# %%
# Connect to pre-computed KPI database
kpi_con = duckdb.connect('data/hospital_analytics.duckdb', read_only=True)

# Connect to worksheet database for raw data
worksheet_con = duckdb.connect('data/hospital_worksheets.duckdb', read_only=True)

print("✓ Connected to both databases")
print(f"  - KPI database: hospital_analytics.duckdb")
print(f"  - Worksheet database: hospital_worksheets.duckdb")
# Out:
# ✓ Connected to both databases
#   - KPI database: hospital_analytics.duckdb
#   - Worksheet database: hospital_worksheets.duckdb

# %%
kpi_con = duckdb.connect('data/hospital_analytics.duckdb', read_only=True)

# Get all tables as a list of tuples
tables = kpi_con.execute("SHOW TABLES").fetchall()
table_names = [row[0] for row in tables]

# Or get as pandas DataFrame (if pandas is available)
import pandas as pd
tables_df = kpi_con.execute("SHOW TABLES").df()
table_names = tables_df['name'].tolist()

print("Available tables:")
for name in table_names:
    print(f"  - {name}")

kpi_con.close()
# Out:
# Available tables:
#   - balance_sheet
#   - costs_a000
#   - costs_b100
#   - fund_balance_changes
#   - hospital_benchmarks
#   - hospital_kpis
#   - hospital_metadata
#   - revenue
#   - revenue_expenses

# %%
kpi_con = duckdb.connect('data/hospital_analytics.duckdb', read_only=True)
kpi_con.execute("select distinct State_Code from balance_sheet limit 10").df()
# Out:
#    State_Code
# 0          31
# 1          14

# %%
worksheet_con = duckdb.connect('data/hospital_worksheets.duckdb', read_only=True)

# Get all tables as a list of tuples
tables = kpi_con
table_names = [row[0] for row in tables]

# Or get as pandas DataFrame (if pandas is available)
import pandas as pd
tables_df = worksheet_con.execute("SHOW TABLES").df()
table_names = tables_df['name'].tolist()

print("Available tables:")
for name in table_names:
    print(f"  - {name}")

worksheet_con.close()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 5
#       3 # Get all tables as a list of tuples
#       4 tables = kpi_con
# ----> 5 table_names = [row[0] for row in tables]
#       7 # Or get as pandas DataFrame (if pandas is available)
#       8 import pandas as pd
#
# TypeError: '_duckdb.DuckDBPyConnection' object is not iterable

# %%
worksheet_con = duckdb.connect('data/hospital_worksheets.duckdb', read_only=True)
worksheet_con.execute("select * from worksheet_s500000 limit 10").df()
worksheet_con.close()
