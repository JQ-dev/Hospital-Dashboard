# %% [markdown]
# ## Hospital Financial Reports Explorer (Parquet Version)

# %%
# Import required libraries
import duckdb
import pandas as pd
import numpy as np
from pathlib import Path
import ipywidgets as widgets
from IPython.display import display, HTML
import warnings
warnings.filterwarnings('ignore')

# Set display options
pd.set_option('display.max_rows', 100)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.float_format', '{:.2f}'.format)

print("✓ Libraries imported successfully")
# Out:
# ✓ Libraries imported successfully

# %%
# Define parquet paths
DATA_ROOT = Path('data/db_parquets')

BALANCE_SHEET_PATH = str(DATA_ROOT / 'balance_sheet_long' / '**/*.parquet')
FUND_BALANCE_CHANGES_PATH = str(DATA_ROOT / 'fund_balance_changes_long' / '**/*.parquet')
REVENUE_PATH = str(DATA_ROOT / 'revenue_long' / '**/*.parquet')
REVENUE_EXPENSES_PATH = str(DATA_ROOT / 'revenue_expenses_long' / '**/*.parquet')
COSTS_A000_PATH = str(DATA_ROOT / 'costs_a000_long' / '**/*.parquet')
COSTS_B100_PATH = str(DATA_ROOT / 'costs_b100_long' / '**/*.parquet')

print(f"✓ Data root: {DATA_ROOT}")
print(f"✓ Parquet paths configured")
# Out:
# ✓ Data root: data\db_parquets
# ✓ Parquet paths configured

# %%
# Get available hospitals and years from parquet files
con = duckdb.connect(':memory:')

# Get hospitals with their metadata
hospitals_df = con.execute(f"""
    SELECT DISTINCT 
        Provider_Number,
        State_Code
    FROM read_parquet('{BALANCE_SHEET_PATH}', hive_partitioning=1)
    ORDER BY Provider_Number
""").df()

# Get available fiscal years
years_df = con.execute(f"""
    SELECT DISTINCT Fiscal_Year
    FROM read_parquet('{BALANCE_SHEET_PATH}', hive_partitioning=1)
    ORDER BY Fiscal_Year DESC
""").df()

con.close()

print(f"✓ Found {len(hospitals_df)} hospitals")
print(f"✓ Fiscal years available: {', '.join(map(str, years_df['Fiscal_Year'].tolist()))}")
# Out:
# ✓ Found 104 hospitals
# ✓ Fiscal years available: 2024, 2023, 2022, 2021, 2020

# %% [markdown]
# ## Selection Controls
#
# Select a hospital (CCN) and fiscal year to view financial reports.

# %%
# Create selection widgets
ccn_options = [(f"{row['Provider_Number']} - {row['State_Code']}", row['Provider_Number']) 
               for _, row in hospitals_df.iterrows()]

ccn_dropdown = widgets.Dropdown(
    options=ccn_options,
    description='Hospital CCN:',
    style={'description_width': 'initial'},
    layout=widgets.Layout(width='400px')
)

year_dropdown = widgets.Dropdown(
    options=[(str(year), year) for year in years_df['Fiscal_Year'].tolist()],
    description='Fiscal Year:',
    style={'description_width': 'initial'},
    layout=widgets.Layout(width='200px')
)

fund_dropdown = widgets.Dropdown(
    options=['General Fund', 'Specific Purpose Fund', 'Endowment Fund', 'Plant Fund'],
    value='General Fund',
    description='Fund Type:',
    style={'description_width': 'initial'},
    layout=widgets.Layout(width='300px')
)

display(widgets.HBox([ccn_dropdown, year_dropdown, fund_dropdown]))
print("\n👆 Select hospital, year, and fund type above")
# Out:
# HBox(children=(Dropdown(description='Hospital CCN:', layout=Layout(width='400px'), options=(('31300 - 31', np.…
# 👆 Select hospital, year, and fund type above

# %% [markdown]
# ## Helper Functions

# %%
def format_millions(value):
    """Format value in millions with 2 decimals"""
    if pd.isna(value) or value == 0:
        return 0.00
    return round(value / 1e6, 2)

def style_dataframe(df):
    """Apply styling to dataframe for better readability"""
    return df.style.format({
        col: '{:.2f}' for col in df.select_dtypes(include=[np.number]).columns
    }).set_properties(**{
        'text-align': 'right'
    }, subset=df.select_dtypes(include=[np.number]).columns).set_properties(**{
        'text-align': 'left'
    }, subset=df.select_dtypes(include=['object']).columns)

print("✓ Helper functions defined")
# Out:
# ✓ Helper functions defined

# %% [markdown]
# ## 1️⃣ Balance Sheet

# %%
def get_balance_sheet(ccn, year, fund_type='General Fund'):
    """Get balance sheet for a specific hospital, year, and fund type"""
    con = duckdb.connect(':memory:')
    
    df = con.execute(f"""
        SELECT
            Acc_level1 as Category,
            Acc_level2 as Subcategory,
            Acc_name as Account,
            Line as Line_Number,
            Value
        FROM read_parquet('{BALANCE_SHEET_PATH}', hive_partitioning=1)
        WHERE Provider_Number = ?
            AND Fiscal_Year = ?
            AND Column_name = ?
        ORDER BY Line
    """, [int(ccn), int(year), fund_type]).df()
    
    con.close()
    
    if df.empty:
        print(f"⚠️ No balance sheet data found for CCN {ccn}, Year {year}, Fund {fund_type}")
        return None
    
    # Convert to millions
    df['Value ($ Millions)'] = df['Value'].apply(format_millions)
    df = df.drop('Value', axis=1)
    
    return df

# Get and display balance sheet
balance_sheet = get_balance_sheet(ccn_dropdown.value, year_dropdown.value, fund_dropdown.value)

if balance_sheet is not None:
    print(f"\n📊 Balance Sheet - {fund_dropdown.value}")
    print(f"CCN: {ccn_dropdown.value} | Fiscal Year: {year_dropdown.value}")
    print(f"Note: All amounts in millions (USD)")
    print(f"Total records: {len(balance_sheet):,}\n")
    display(style_dataframe(balance_sheet))
# Out:
# 📊 Balance Sheet - General Fund
# CCN: 31300 | Fiscal Year: 2024
# Note: All amounts in millions (USD)
# Total records: 32
# <style type="text/css">
# #T_95268_row0_col0, #T_95268_row0_col1, #T_95268_row0_col2, #T_95268_row0_col3, #T_95268_row1_col0, #T_95268_row1_col1, #T_95268_row1_col2, #T_95268_row1_col3, #T_95268_row2_col0, #T_95268_row2_col1, #T_95268_row2_col2, #T_95268_row2_col3, #T_95268_row3_col0, #T_95268_row3_col1, #T_95268_row3_col2, #T_95268_row3_col3, #T_95268_row4_col0, #T_95268_row4_col1, #T_95268_row4_col2, #T_95268_row4_col3, #T_95268_row5_col0, #T_95268_row5_col1, #T_95268_row5_col2, #T_95268_row5_col3, #T_95268_row6_col0, #T_95268_row6_col1, #T_95268_row6_col2, #T_95268_row6_col3, #T_95268_row7_col0, #T_95268_row7_col1, #T_95268_row7_col2, #T_95268_row7_col3, #T_95268_row8_col0, #T_95268_row8_col1, #T_95268_row8_col2, #T_95268_row8_col3, #T_95268_row9_col0, #T_95268_row9_col1, #T_95268_row9_col2, #T_95268_row9_col3, #T_95268_row10_col0, #T_95268_row10_col1, #T_95268_row10_col2, #T_95268_row10_col3, #T_95268_row11_col0, #T_95268_row11_col1, #T_95268_row11_col2, #T_95268_row11_col3, #T_95268_row12_col0, #T_95268_row12_col1, #T_95268_row12_col2, #T_95268_row12_col3, #T_95268_row13_col0, #T_95268_row13_col1, #T_95268_row13_col2, #T_95268_row13_col3, #T_95268_row14_col0, #T_95268_row14_col1, #T_95268_row14_col2, #T_95268_row14_col3, #T_95268_row15_col0, #T_95268_row15_col1, #T_95268_row15_col2, #T_95268_row15_col3, #T_95268_row16_col0, #T_95268_row16_col1, #T_95268_row16_col2, #T_95268_row16_col3, #T_95268_row17_col0, #T_95268_row17_col1, #T_95268_row17_col2, #T_95268_row17_col3, #T_95268_row18_col0, #T_95268_row18_col1, #T_95268_row18_col2, #T_95268_row18_col3, #T_95268_row19_col0, #T_95268_row19_col1, #T_95268_row19_col2, #T_95268_row19_col3, #T_95268_row20_col0, #T_95268_row20_col1, #T_95268_row20_col2, #T_95268_row20_col3, #T_95268_row21_col0, #T_95268_row21_col1, #T_95268_row21_col2, #T_95268_row21_col3, #T_95268_row22_col0, #T_95268_row22_col1, #T_95268_row22_col2, #T_95268_row22_col3, #T_95268_row23_col0, #T_95268_row23_col1, #T_95268_row23_col2, #T_95268_row23_col3, #T_95268_row24_col0, #T_95268_row24_col1, #T_95268_row24_col2, #T_95268_row24_col3, #T_95268_row25_col0, #T_95268_row25_col1, #T_95268_row25_col2, #T_95268_row25_col3, #T_95268_row26_col0, #T_95268_row26_col1, #T_95268_row26_col2, #T_95268_row26_col3, #T_95268_row27_col0, #T_95268_row27_col1, #T_95268_row27_col2, #T_95268_row27_col3, #T_95268_row28_col0, #T_95268_row28_col1, #T_95268_row28_col2, #T_95268_row28_col3, #T_95268_row29_col0, #T_95268_row29_col1, #T_95268_row29_col2, #T_95268_row29_col3, #T_95268_row30_col0, #T_95268_row30_col1, #T_95268_row30_col2, #T_95268_row30_col3, #T_95268_row31_col0, #T_95268_row31_col1, #T_95268_row31_col2, #T_95268_row31_col3 {
#   text-align: left;
# }
# #T_95268_row0_col4, #T_95268_row1_col4, #T_95268_row2_col4, #T_95268_row3_col4, #T_95268_row4_col4, #T_95268_row5_col4, #T_95268_row6_col4, #T_95268_row7_col4, #T_95268_row8_col4, #T_95268_row9_col4, #T_95268_row10_col4, #T_95268_row11_col4, #T_95268_row12_col4, #T_95268_row13_col4, #T_95268_row14_col4, #T_95268_row15_col4, #T_95268_row16_col4, #T_95268_row17_col4, #T_95268_row18_col4, #T_95268_row19_col4, #T_95268_row20_col4, #T_95268_row21_col4, #T_95268_row22_col4, #T_95268_row23_col4, #T_95268_row24_col4, #T_95268_row25_col4, #T_95268_row26_col4, #T_95268_row27_col4, #T_95268_row28_col4, #T_95268_row29_col4, #T_95268_row30_col4, #T_95268_row31_col4 {
#   text-align: right;
# }
# </style>
# <table id="T_95268">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_95268_level0_col0" class="col_heading level0 col0" >Category</th>
#       <th id="T_95268_level0_col1" class="col_heading level0 col1" >Subcategory</th>
#       <th id="T_95268_level0_col2" class="col_heading level0 col2" >Account</th>
#       <th id="T_95268_level0_col3" class="col_heading level0 col3" >Line_Number</th>
#       <th id="T_95268_level0_col4" class="col_heading level0 col4" >Value ($ Millions)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_95268_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_95268_row0_col0" class="data row0 col0" >Balance</td>
#       <td id="T_95268_row0_col1" class="data row0 col1" >Assets</td>
#       <td id="T_95268_row0_col2" class="data row0 col2" >Cash On Hand And In Banks</td>
#       <td id="T_95268_row0_col3" class="data row0 col3" >00100</td>
#       <td id="T_95268_row0_col4" class="data row0 col4" >0.79</td>
#     </tr>
#     <tr>
#       <th id="T_95268_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_95268_row1_col0" class="data row1 col0" >Balance</td>
#       <td id="T_95268_row1_col1" class="data row1 col1" >Assets</td>
#       <td id="T_95268_row1_col2" class="data row1 col2" >Temporary Investments</td>
#       <td id="T_95268_row1_col3" class="data row1 col3" >00200</td>
#       <td id="T_95268_row1_col4" class="data row1 col4" >1.87</td>
#     </tr>
#     <tr>
#       <th id="T_95268_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_95268_row2_col0" class="data row2 col0" >Balance</td>
#       <td id="T_95268_row2_col1" class="data row2 col1" >Assets</td>
#       <td id="T_95268_row2_col2" class="data row2 col2" >Accounts Receivable</td>
#       <td id="T_95268_row2_col3" class="data row2 col3" >00400</td>
#       <td id="T_95268_row2_col4" class="data row2 col4" >25.16</td>
#     </tr>
#     <tr>
#       <th id="T_95268_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_95268_row3_col0" class="data row3 col0" >Balance</td>
#       <td id="T_95268_row3_col1" class="data row3 col1" >Assets</td>
#       <td id="T_95268_row3_col2" class="data row3 col2" >Other Receivables</td>
#       <td id="T_95268_row3_col3" class="data row3 col3" >00500</td>
#       <td id="T_95268_row3_col4" class="data row3 col4" >0.62</td>
#     </tr>
#     <tr>
#       <th id="T_95268_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_95268_row4_col0" class="data row4 col0" >Balance</td>
#       <td id="T_95268_row4_col1" class="data row4 col1" >Assets</td>
#       <td id="T_95268_row4_col2" class="data row4 col2" >Allowances For Uncollectible Notes And Accounts Receivable</td>
#       <td id="T_95268_row4_col3" class="data row4 col3" >00600</td>
#       <td id="T_95268_row4_col4" class="data row4 col4" >-17.70</td>
#     </tr>
#     <tr>
#       <th id="T_95268_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_95268_row5_col0" class="data row5 col0" >Balance</td>
#       <td id="T_95268_row5_col1" class="data row5 col1" >Assets</td>
#       <td id="T_95268_row5_col2" class="data row5 col2" >Inventory</td>
#       <td id="T_95268_row5_col3" class="data row5 col3" >00700</td>
#       <td id="T_95268_row5_col4" class="data row5 col4" >1.14</td>
#     </tr>
#     <tr>
#       <th id="T_95268_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_95268_row6_col0" class="data row6 col0" >Balance</td>
#       <td id="T_95268_row6_col1" class="data row6 col1" >Assets</td>
#       <td id="T_95268_row6_col2" class="data row6 col2" >Prepaid Expenses</td>
#       <td id="T_95268_row6_col3" class="data row6 col3" >00800</td>
#       <td id="T_95268_row6_col4" class="data row6 col4" >0.43</td>
#     </tr>
#     <tr>
#       <th id="T_95268_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_95268_row7_col0" class="data row7 col0" >Balance</td>
#       <td id="T_95268_row7_col1" class="data row7 col1" >Assets</td>
#       <td id="T_95268_row7_col2" class="data row7 col2" >Total Current Assets</td>
#       <td id="T_95268_row7_col3" class="data row7 col3" >01100</td>
#       <td id="T_95268_row7_col4" class="data row7 col4" >12.31</td>
#     </tr>
#     <tr>
#       <th id="T_95268_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_95268_row8_col0" class="data row8 col0" >Balance</td>
#       <td id="T_95268_row8_col1" class="data row8 col1" >Assets</td>
#       <td id="T_95268_row8_col2" class="data row8 col2" >Land</td>
#       <td id="T_95268_row8_col3" class="data row8 col3" >01200</td>
#       <td id="T_95268_row8_col4" class="data row8 col4" >1.92</td>
#     </tr

# %%
def get_balance_sheet(ccn, year, fund_type='General Fund'):
    con = duckdb.connect(':memory:')
    
    df = con.execute(f"""
        SELECT
            *
        FROM read_parquet('{BALANCE_SHEET_PATH}', hive_partitioning=1)
        WHERE Provider_Number = ?
            AND Fiscal_Year = ?
    """, [int(ccn), int(year)]).df()
    
    con.close()
    
    if df.empty:
        print(f"⚠️ No balance sheet data found for CCN {ccn}, Year {year}, Fund {fund_type}")
        return None
    
    # Convert to millions
    df['Value ($ Millions)'] = df['Value'].apply(format_millions)
    df = df.drop('Value', axis=1)
    
    return df

# Get and display balance sheet
balance_sheet = get_balance_sheet(ccn_dropdown.value, year_dropdown.value, fund_dropdown.value)

balance_sheet
# Out:
#     Provider_Number  Year                                       Account_Name  \
# 0             31300  2024     General_Fund_BAL_ASSE_CURR_Accounts_receivable
# 1             31300  2024  General_Fund_BAL_ASSE_CURR_Allowances_for_unco...
# 2             31300  2024  General_Fund_BAL_ASSE_CURR_Cash_on_hand_and_in...
# 3             31300  2024               General_Fund_BAL_ASSE_CURR_Inventory
# 4             31300  2024       General_Fund_BAL_ASSE_CURR_Other_receivables
# 5             31300  2024        General_Fund_BAL_ASSE_CURR_Prepaid_expenses
# 6             31300  2024   General_Fund_BAL_ASSE_CURR_Temporary_investments
# 7             31300  2024  General_Fund_BAL_ASSE_CURR_Total_current_asset...
# 8             31300  2024  General_Fund_BAL_ASSE_FIXE_Accumulated_depreci...
# 9             31300  2024  General_Fund_BAL_ASSE_FIXE_Accumulated_depreci...
# 10            31300  2024  General_Fund_BAL_ASSE_FIXE_Accumulated_depreci...
# 11            31300  2024               General_Fund_BAL_ASSE_FIXE_Buildings
# 12            31300  2024                   General_Fund_BAL_ASSE_FIXE_Land_
# 13            31300  2024       General_Fund_BAL_ASSE_FIXE_Land_improvements
# 14            31300  2024  General_Fund_BAL_ASSE_FIXE_Major_movable_equip...
# 15            31300  2024  General_Fund_BAL_ASSE_FIXE_Total_fixed_assets_...
# 16            31300  2024             General_Fund_BAL_ASSE_OTHE_Investments
# 17            31300  2024            General_Fund_BAL_ASSE_OTHE_Other_assets
# 18            31300  2024  General_Fund_BAL_ASSE_OTHE_Total_assets_sum_of...
# 19            31300  2024  General_Fund_BAL_ASSE_OTHE_Total_other_assets_...
# 20            31300  2024    General_Fund_BAL_FUND_CAPI_General_fund_balance
# 21            31300  2024    General_Fund_BAL_FUND_CAPI_Total_fund_balances_
# 22            31300  2024  General_Fund_BAL_FUND_CAPI_Total_liabilities_a...
# 23            31300  2024        General_Fund_BAL_LIAB_CURR_Accounts_payable
# 24            31300  2024  General_Fund_BAL_LIAB_CURR_Notes_and_loans_pay...
# 25            31300  2024  General_Fund_BAL_LIAB_CURR_Other_current_liabi...
# 26            31300  2024  General_Fund_BAL_LIAB_CURR_Salaries_wages_and_...
# 27            31300  2024  General_Fund_BAL_LIAB_CURR_Total_current_liabi...
# 28            31300  2024           General_Fund_BAL_LIAB_LONG_Notes_payable
# 29            31300  2024  General_Fund_BAL_LIAB_LONG_Other_long_term_lia...
# 30            31300  2024  General_Fund_BAL_LIAB_LONG_Total_liabilities_s...
# 31            31300  2024  General_Fund_BAL_LIAB_LONG_Total_long_term_lia...
#
#     NPI  Control_Type  Report_Status    FY_Begin     FY_End  Geographic_Code  \
# 0   NaN             2              1  01/01/2024 2024-12-31             5901
# 1   NaN             2              1  01/01/2024 2024-12-31             5901
# 2   NaN             2              1  01/01/2024 2024-12-31             5901
# 3   NaN             2              1  01/01/2024 2024-12-31             5901
# 4   NaN             2              1  01/01/2024 2024-12-31             5901
# 5   NaN             2              1  01/01/2024 2024-12-31             5901
# 6   NaN             2              1  01/01/2024 2024-12-31             5901
# 7   NaN             2              1  01/01/2024 2024-12-31             5901
# 8   NaN             2              1  01/01/2024 2024-12-31             5901
# 9   NaN             2              1  01/01/2024 2024-12-31             5901
# 10  NaN             2              1  01/01/2024 2024-12-31             5901
# 11  NaN             2              1  01/01/2024 2024-12-31             5901
# 12  NaN             2              1  01/01/2024 2024-12-31             5901
# 13  NaN             2              1  01/01/2024 2024-12-31             5901
# 14  NaN             2              1  01/01/2024 2024-12-31             5901
# 15  NaN             2              1  01/01/2024 2024-12-31             5901
# 16  NaN             2              1  01/01/2024 2024-12-31             5901
# 17  NaN             2              1  01/01/2024 2024-12-31             5901
# 18  NaN             2              1  01/01/2024 2024-12-31             5901
# 19  NaN             2              1  01/01/2024 2024-12-31             5901
# 20  NaN             2              1  01/01/2024 2024-12-31             5901
# 21  NaN             2              1  01/01/2024 2024-12-31             5901
# 22  NaN             2              1  01/01/2024 2024-12-31             5901
# 23  NaN             2              1  01/01/2024 2024-12-31             5901
# 24  NaN             2              1  01/01/2024 2024-12-31             5901
# 25  NaN             2              1  01/01/2024 2024-12-31             5901
# 26  NaN             2              1  01/01/2024 2024-12-31             5901
# 27  NaN             2              1  01/01/2024 2024-12-31             5901
# 28  NaN             2              1  01/01/2024 2024-12-31             5901
# 29  NaN             2              1  01/01/2024 2024-12-31             5901
# 30  NaN             2              1  01/01/2024 2024-12-31             5901
# 31  NaN             2              1  01/01/2024 2024-12-31             5901
#
#    Worksheet   Line Column   Column_name Acc_level1     Acc_level2  \
# 0    G000000  00400  00100  General Fund    Balance         Assets
# 1    G000000  00600  00100  General Fund    Balance         Assets
# 2    G000000  00100  00100  General Fund    Balance         Assets
# 3    G000000  00700  00100  General Fund    Balance         Assets
# 4    G000000  00500  00100  General Fund    Balance         Assets
# 5    G000000  00800  00100  General Fund    Balance         Assets
# 6    G000000  00200  00100  General Fund    Balance         Assets
# 7    G000000  01100  00100  General Fund    Balance         Assets
# 8    G000000  01400  00100  General Fund    Balance         Assets
# 9    G000000  01600  00100  General Fund    Balance         Assets
# 10   G000000  02400  00100  General Fund    Balance         Assets
# 11   G000000  01500  00100  General Fund    Balance         Assets
# 12   G000000  01200  00100  General Fund    Balance         Assets
# 13   G000000  01300  00100  General Fund    Balance         Assets
# 14   G000000  02300  00100  General Fund    Balance         Assets
# 15   G000000  03000  00100  General Fund    Balance         Assets
# 16   G000000  03100  00100  General Fund    Balance         Assets
# 17   G000000  03400  00100  General Fund    Balance         Assets
# 18   G000000  03600  00100  General Fund    Balance         Assets
# 19   G000000  03500  00100  General Fund    Balance         Assets
# 20   G000000  05200  00100  General Fund    Balance  Fund Balances
# 21   G000000  05900  00100  General Fund    Balance  Fund Balances
# 22   G000000  06000  00100  General Fund    Balance  Fund Balances
# 23   G000000  03700  00100  General Fund    Balance    Liabilities
# 24   G000000  04000  00100  General Fund    Balance    Liabilities
# 25   G000000  04400  00100  General Fund    Balance    Liabilities
# 26   G000000  03800  00100  General Fund    Balance    Liabilities
# 27   G000000  04500  00100  General Fund    Balance    Liabilities
# 28   G000000  04700  00100  General Fund    Balance    Liabilities
# 29   G000000  04900  00100  General Fund    Balance    Liabilities
# 30   G000000  05100  00100  General Fund    Balance    Liabilities
# 31   G000000  05000  00100  General Fund    Balance    Liabilities
#
#                Acc_level3                                           Acc_name  \
# 0          Current Assets                                Accounts Receivable
# 1          Current Assets  Allowances For Uncollectible Notes And Account...
# 2          Current Assets                          Cash On Hand And In Banks
# 3          Current Assets                                          Inventory
# 4          Current Assets                                  Other Receivables
# 5          Current Assets                                   Prepaid Expenses
# 6          Current Assets                              Temporary Investments
# 7          Current Assets                               Total Current Assets
# 8            Fixed Assets                           Accumulated Depreciation
# 9            Fixed Assets                           Accumulated Depreciation
# 10           Fixed Assets                           Accumulated Depreciation
# 11           Fixed Assets                                          Buildings
# 12           Fixed Assets                                               Land
# 13           Fixed Assets                                  Land Improvements
# 14           Fixed Assets                            Major Movable Equipment
# 15           Fixed Assets                                 Total Fixed Assets
# 16           Other Assets                                        Investments
# 17           Other Assets                                       Other Assets
# 18           Other Assets                                       Total Assets
# 19           Other Assets                                 Total Other Assets
# 20  Long term Liabilities                               General Fund Balance
# 21       Capital Accounts                                Total Fund Balances
# 22       Capital Accounts                Total Liabilities And Fund Balances
# 23    Current Liabilities                                   Accounts Payable
# 24    Current Liabilities               Notes And Loans Payable (Short Term)
# 25    Current Liabilities                          Other Current Liabilities
# 26    Current Liabilities                  Salaries, Wages, And Fees Payable
# 27    Current Liabilities                          Total Current Liabilities
# 28  Long term Liabilities                                      Notes Payable
# 29  Long term Liabilities                        Other Long Term Liabilities
# 30  Long term Liabilities                                  Total Liabilities
# 31  Long term Liabilities                        Total Long Term Liabilities
#
#     Fiscal_Year  State_Code  Value ($ Millions)
# 0          2024          31               25.16
# 1          2024          31              -17.70
# 2          2024          31                0.79
# 3          2024          31                1.14
# 4          2024          31                0.62
# 5          2024          31                0.43
# 6          2024          31                1.87
# 7          2024          31               12.31
# 8          2024          31               -0.31
# 9          2024          31              -10.86
# 10         2024          31              -10.58
# 11         2024          31               21.76
# 12         2024          31                1.92
# 13         2024          31                0.56
# 14         2024          31               15.58
# 15         2024          31               18.06
# 16         2024          31                0.44
# 17         2024          31                1.12
# 18         2024          31               31.93
# 19         2024          31                1.56
# 20         2024          31                6.63
# 21         2024          31                6.63
# 22         2024          31               31.93
# 23         2024          31                4.94
# 24         2024          31                2.24
# 25         2024          31                1.42
# 26         2024          31                1.13
# 27         2024          31                9.73
# 28         2024          31               13.18
# 29         2024          31                2.39
# 30         2024          31               25.30
# 31         2024          31               15.57

# %% [markdown]
# ## 2️⃣ Fund Balance Changes

# %%
def get_fund_balance_changes(ccn, year):
    """Get fund balance changes for a specific hospital and year"""
    con = duckdb.connect(':memory:')
    
    df = con.execute(f"""
        SELECT
            Acc_level1 as Category,
            Acc_level2 as Subcategory,
            Acc_name as Account,
            Line as Line_Number,
            Value
        FROM read_parquet('{FUND_BALANCE_CHANGES_PATH}', hive_partitioning=1)
        WHERE Provider_Number = ?
            AND Fiscal_Year = ?
        ORDER BY Line
    """, [int(ccn), int(year)]).df()
    
    con.close()
    
    if df.empty:
        print(f"⚠️ No fund balance changes data found for CCN {ccn}, Year {year}")
        return None
    
    # Convert to millions
    df['Value ($ Millions)'] = df['Value'].apply(format_millions)
    df = df.drop('Value', axis=1)
    
    return df

# Get and display fund balance changes
fund_changes = get_fund_balance_changes(ccn_dropdown.value, year_dropdown.value)

if fund_changes is not None:
    print(f"\n💼 Fund Balance Changes")
    print(f"CCN: {ccn_dropdown.value} | Fiscal Year: {year_dropdown.value}")
    print(f"Note: All amounts in millions (USD)")
    print(f"Total records: {len(fund_changes):,}\n")
    display(style_dataframe(fund_changes))
# Out:
# 💼 Fund Balance Changes
# CCN: 31300 | Fiscal Year: 2024
# Note: All amounts in millions (USD)
# Total records: 7
# <style type="text/css">
# #T_1e9d1_row0_col0, #T_1e9d1_row0_col2, #T_1e9d1_row0_col3, #T_1e9d1_row1_col0, #T_1e9d1_row1_col2, #T_1e9d1_row1_col3, #T_1e9d1_row2_col0, #T_1e9d1_row2_col2, #T_1e9d1_row2_col3, #T_1e9d1_row3_col0, #T_1e9d1_row3_col2, #T_1e9d1_row3_col3, #T_1e9d1_row4_col0, #T_1e9d1_row4_col2, #T_1e9d1_row4_col3, #T_1e9d1_row5_col0, #T_1e9d1_row5_col2, #T_1e9d1_row5_col3, #T_1e9d1_row6_col0, #T_1e9d1_row6_col2, #T_1e9d1_row6_col3 {
#   text-align: left;
# }
# #T_1e9d1_row0_col1, #T_1e9d1_row0_col4, #T_1e9d1_row1_col1, #T_1e9d1_row1_col4, #T_1e9d1_row2_col1, #T_1e9d1_row2_col4, #T_1e9d1_row3_col1, #T_1e9d1_row3_col4, #T_1e9d1_row4_col1, #T_1e9d1_row4_col4, #T_1e9d1_row5_col1, #T_1e9d1_row5_col4, #T_1e9d1_row6_col1, #T_1e9d1_row6_col4 {
#   text-align: right;
# }
# </style>
# <table id="T_1e9d1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1e9d1_level0_col0" class="col_heading level0 col0" >Category</th>
#       <th id="T_1e9d1_level0_col1" class="col_heading level0 col1" >Subcategory</th>
#       <th id="T_1e9d1_level0_col2" class="col_heading level0 col2" >Account</th>
#       <th id="T_1e9d1_level0_col3" class="col_heading level0 col3" >Line_Number</th>
#       <th id="T_1e9d1_level0_col4" class="col_heading level0 col4" >Value ($ Millions)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1e9d1_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1e9d1_row0_col0" class="data row0 col0" >Changes in Fund Balances</td>
#       <td id="T_1e9d1_row0_col1" class="data row0 col1" ><NA></td>
#       <td id="T_1e9d1_row0_col2" class="data row0 col2" > Fund balances at beginning of period</td>
#       <td id="T_1e9d1_row0_col3" class="data row0 col3" >00100</td>
#       <td id="T_1e9d1_row0_col4" class="data row0 col4" >5.58</td>
#     </tr>
#     <tr>
#       <th id="T_1e9d1_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1e9d1_row1_col0" class="data row1 col0" >Changes in Fund Balances</td>
#       <td id="T_1e9d1_row1_col1" class="data row1 col1" ><NA></td>
#       <td id="T_1e9d1_row1_col2" class="data row1 col2" > Net income (loss)</td>
#       <td id="T_1e9d1_row1_col3" class="data row1 col3" >00200</td>
#       <td id="T_1e9d1_row1_col4" class="data row1 col4" >1.31</td>
#     </tr>
#     <tr>
#       <th id="T_1e9d1_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1e9d1_row2_col0" class="data row2 col0" >Changes in Fund Balances</td>
#       <td id="T_1e9d1_row2_col1" class="data row2 col1" ><NA></td>
#       <td id="T_1e9d1_row2_col2" class="data row2 col2" > Total</td>
#       <td id="T_1e9d1_row2_col3" class="data row2 col3" >00300</td>
#       <td id="T_1e9d1_row2_col4" class="data row2 col4" >6.89</td>
#     </tr>
#     <tr>
#       <th id="T_1e9d1_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1e9d1_row3_col0" class="data row3 col0" >Changes in Fund Balances</td>
#       <td id="T_1e9d1_row3_col1" class="data row3 col1" ><NA></td>
#       <td id="T_1e9d1_row3_col2" class="data row3 col2" > Subtotal</td>
#       <td id="T_1e9d1_row3_col3" class="data row3 col3" >01100</td>
#       <td id="T_1e9d1_row3_col4" class="data row3 col4" >6.89</td>
#     </tr>
#     <tr>
#       <th id="T_1e9d1_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1e9d1_row4_col0" class="data row4 col0" >Changes in Fund Balances</td>
#       <td id="T_1e9d1_row4_col1" class="data row4 col1" ><NA></td>
#       <td id="T_1e9d1_row4_col2" class="data row4 col2" >Deduction 1</td>
#       <td id="T_1e9d1_row4_col3" class="data row4 col3" >01200</td>
#       <td id="T_1e9d1_row4_col4" class="data row4 col4" >0.26</td>
#     </tr>
#     <tr>
#       <th id="T_1e9d1_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1e9d1_row5_col0" class="data row5 col0" >Changes in Fund Balances</td>
#       <td id="T_1e9d1_row5_col1" class="data row5 col1" ><NA></td>
#       <td id="T_1e9d1_row5_col2" class="data row5 col2" > Total deductions </td>
#       <td id="T_1e9d1_row5_col3" class="data row5 col3" >01800</td>
#       <td id="T_1e9d1_row5_col4" class="data row5 col4" >0.26</td>
#     </tr>
#     <tr>
#       <th id="T_1e9d1_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1e9d1_row6_col0" class="data row6 col0" >Changes in Fund Balances</td>
#       <td id="T_1e9d1_row6_col1" class="data row6 col1" ><NA></td>
#       <td id="T_1e9d1_row6_col2" class="data row6 col2" > Fund balance at end of period per balance  sheet</td>
#       <td id="T_1e9d1_row6_col3" class="data row6 col3" >01900</td>
#       <td id="T_1e9d1_row6_col4" class="data row6 col4" >6.63</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## 3️⃣ Revenue Detail

# %%
def get_revenue(ccn, year):
    """Get revenue detail for a specific hospital and year"""
    con = duckdb.connect(':memory:')
    
    df = con.execute(f"""
        SELECT
            Revenue_Group as Revenue_Category,
            Revenue_Subgroup as Revenue_Subcategory,
            Revenue_Center,
            Revenue_Line_Name as Account,
            Line as Line_Number,
            Value
        FROM read_parquet('{REVENUE_PATH}', hive_partitioning=1)
        WHERE Provider_Number = ?
            AND Fiscal_Year = ?
        ORDER BY Line
    """, [int(ccn), int(year)]).df()
    
    con.close()
    
    if df.empty:
        print(f"⚠️ No revenue data found for CCN {ccn}, Year {year}")
        return None
    
    # Convert to millions
    df['Value ($ Millions)'] = df['Value'].apply(format_millions)
    df = df.drop('Value', axis=1)
    
    return df

# Get and display revenue
revenue = get_revenue(ccn_dropdown.value, year_dropdown.value)

if revenue is not None:
    print(f"\n💰 Revenue Detail")
    print(f"CCN: {ccn_dropdown.value} | Fiscal Year: {year_dropdown.value}")
    print(f"Note: All amounts in millions (USD)")
    print(f"Total records: {len(revenue):,}\n")
    display(style_dataframe(revenue))
# Out:
# 💰 Revenue Detail
# CCN: 31300 | Fiscal Year: 2024
# Note: All amounts in millions (USD)
# Total records: 19
# <style type="text/css">
# #T_81c5c_row0_col0, #T_81c5c_row0_col1, #T_81c5c_row0_col2, #T_81c5c_row0_col3, #T_81c5c_row0_col4, #T_81c5c_row1_col0, #T_81c5c_row1_col1, #T_81c5c_row1_col2, #T_81c5c_row1_col3, #T_81c5c_row1_col4, #T_81c5c_row2_col0, #T_81c5c_row2_col1, #T_81c5c_row2_col2, #T_81c5c_row2_col3, #T_81c5c_row2_col4, #T_81c5c_row3_col0, #T_81c5c_row3_col1, #T_81c5c_row3_col2, #T_81c5c_row3_col3, #T_81c5c_row3_col4, #T_81c5c_row4_col0, #T_81c5c_row4_col1, #T_81c5c_row4_col2, #T_81c5c_row4_col3, #T_81c5c_row4_col4, #T_81c5c_row5_col0, #T_81c5c_row5_col1, #T_81c5c_row5_col2, #T_81c5c_row5_col3, #T_81c5c_row5_col4, #T_81c5c_row6_col0, #T_81c5c_row6_col1, #T_81c5c_row6_col2, #T_81c5c_row6_col3, #T_81c5c_row6_col4, #T_81c5c_row7_col0, #T_81c5c_row7_col1, #T_81c5c_row7_col2, #T_81c5c_row7_col3, #T_81c5c_row7_col4, #T_81c5c_row8_col0, #T_81c5c_row8_col1, #T_81c5c_row8_col2, #T_81c5c_row8_col3, #T_81c5c_row8_col4, #T_81c5c_row9_col0, #T_81c5c_row9_col1, #T_81c5c_row9_col2, #T_81c5c_row9_col3, #T_81c5c_row9_col4, #T_81c5c_row10_col0, #T_81c5c_row10_col1, #T_81c5c_row10_col2, #T_81c5c_row10_col3, #T_81c5c_row10_col4, #T_81c5c_row11_col0, #T_81c5c_row11_col1, #T_81c5c_row11_col2, #T_81c5c_row11_col3, #T_81c5c_row11_col4, #T_81c5c_row12_col0, #T_81c5c_row12_col1, #T_81c5c_row12_col2, #T_81c5c_row12_col3, #T_81c5c_row12_col4, #T_81c5c_row13_col0, #T_81c5c_row13_col1, #T_81c5c_row13_col2, #T_81c5c_row13_col3, #T_81c5c_row13_col4, #T_81c5c_row14_col0, #T_81c5c_row14_col1, #T_81c5c_row14_col2, #T_81c5c_row14_col3, #T_81c5c_row14_col4, #T_81c5c_row15_col0, #T_81c5c_row15_col1, #T_81c5c_row15_col2, #T_81c5c_row15_col3, #T_81c5c_row15_col4, #T_81c5c_row16_col0, #T_81c5c_row16_col1, #T_81c5c_row16_col2, #T_81c5c_row16_col3, #T_81c5c_row16_col4, #T_81c5c_row17_col0, #T_81c5c_row17_col1, #T_81c5c_row17_col2, #T_81c5c_row17_col3, #T_81c5c_row17_col4, #T_81c5c_row18_col0, #T_81c5c_row18_col1, #T_81c5c_row18_col2, #T_81c5c_row18_col3, #T_81c5c_row18_col4 {
#   text-align: left;
# }
# #T_81c5c_row0_col5, #T_81c5c_row1_col5, #T_81c5c_row2_col5, #T_81c5c_row3_col5, #T_81c5c_row4_col5, #T_81c5c_row5_col5, #T_81c5c_row6_col5, #T_81c5c_row7_col5, #T_81c5c_row8_col5, #T_81c5c_row9_col5, #T_81c5c_row10_col5, #T_81c5c_row11_col5, #T_81c5c_row12_col5, #T_81c5c_row13_col5, #T_81c5c_row14_col5, #T_81c5c_row15_col5, #T_81c5c_row16_col5, #T_81c5c_row17_col5, #T_81c5c_row18_col5 {
#   text-align: right;
# }
# </style>
# <table id="T_81c5c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_81c5c_level0_col0" class="col_heading level0 col0" >Revenue_Category</th>
#       <th id="T_81c5c_level0_col1" class="col_heading level0 col1" >Revenue_Subcategory</th>
#       <th id="T_81c5c_level0_col2" class="col_heading level0 col2" >Revenue_Center</th>
#       <th id="T_81c5c_level0_col3" class="col_heading level0 col3" >Account</th>
#       <th id="T_81c5c_level0_col4" class="col_heading level0 col4" >Line_Number</th>
#       <th id="T_81c5c_level0_col5" class="col_heading level0 col5" >Value ($ Millions)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_81c5c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_81c5c_row0_col0" class="data row0 col0" >Patient Revenues</td>
#       <td id="T_81c5c_row0_col1" class="data row0 col1" >General Inpatient Routine Care Services</td>
#       <td id="T_81c5c_row0_col2" class="data row0 col2" >Inpatient</td>
#       <td id="T_81c5c_row0_col3" class="data row0 col3" >PatRev  IPgral Hospital</td>
#       <td id="T_81c5c_row0_col4" class="data row0 col4" >00100</td>
#       <td id="T_81c5c_row0_col5" class="data row0 col5" >2.52</td>
#     </tr>
#     <tr>
#       <th id="T_81c5c_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_81c5c_row1_col0" class="data row1 col0" >Patient Revenues</td>
#       <td id="T_81c5c_row1_col1" class="data row1 col1" >General Inpatient Routine Care Services</td>
#       <td id="T_81c5c_row1_col2" class="data row1 col2" >Total</td>
#       <td id="T_81c5c_row1_col3" class="data row1 col3" >PatRev  IPgral Hospital</td>
#       <td id="T_81c5c_row1_col4" class="data row1 col4" >00100</td>
#       <td id="T_81c5c_row1_col5" class="data row1 col5" >2.52</td>
#     </tr>
#     <tr>
#       <th id="T_81c5c_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_81c5c_row2_col0" class="data row2 col0" >Patient Revenues</td>
#       <td id="T_81c5c_row2_col1" class="data row2 col1" >General Inpatient Routine Care Services</td>
#       <td id="T_81c5c_row2_col2" class="data row2 col2" >Inpatient</td>
#       <td id="T_81c5c_row2_col3" class="data row2 col3" >PatRev  IPgral Total general inpatient care services </td>
#       <td id="T_81c5c_row2_col4" class="data row2 col4" >01000</td>
#       <td id="T_81c5c_row2_col5" class="data row2 col5" >2.52</td>
#     </tr>
#     <tr>
#       <th id="T_81c5c_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_81c5c_row3_col0" class="data row3 col0" >Patient Revenues</td>
#       <td id="T_81c5c_row3_col1" class="data row3 col1" >General Inpatient Routine Care Services</td>
#       <td id="T_81c5c_row3_col2" class="data row3 col2" >Total</td>
#       <td id="T_81c5c_row3_col3" class="data row3 col3" >PatRev  IPgral Total general inpatient care services </td>
#       <td id="T_81c5c_row3_col4" class="data row3 col4" >01000</td>
#       <td id="T_81c5c_row3_col5" class="data row3 col5" >2.52</td>
#     </tr>
#     <tr>
#       <th id="T_81c5c_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_81c5c_row4_col0" class="data row4 col0" >Patient Revenues</td>
#       <td id="T_81c5c_row4_col1" class="data row4 col1" >Intensive Care Type Inpatient Hospital Services</td>
#       <td id="T_81c5c_row4_col2" class="data row4 col2" >Inpatient</td>
#       <td id="T_81c5c_row4_col3" class="data row4 col3" >PatRev  IC_IP Total inpatient routine care services </td>
#       <td id="T_81c5c_row4_col4" class="data row4 col4" >01700</td>
#       <td id="T_81c5c_row4_col5" class="data row4 col5" >2.52</td>
#     </tr>
#     <tr>
#       <th id="T_81c5c_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_81c5c_row5_col0" class="data row5 col0" >Patient Revenues</td>
#       <td id="T_81c5c_row5_col1" class="data row5 col1" >Intensive Care Type Inpatient Hospital Services</td>
#       <td id="T_81c5c_row5_col2" class="data row5 col2" >Total</td>
#       <td id="T_81c5c_row5_col3" class="data row5 col3" >PatRev  IC_IP Total inpatient routine care services </td>
#       <td id="T_81c5c_row5_col4" class="data row5 col4" >01700</td>
#       <td id="T_81c5c_row5_col5" class="data row5 col5" >2.52</td>
#     </tr>
#     <tr>
#       <th id="T_81c5c_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_81c5c_row6_col0" class="data row6 col0" >Patient Revenues</td>
#       <td id="T_81c5c_row6_col1" class="data row6 col1" >Intensive Care Type Inpatient Hospital Services</td>
#       <td id="T_81c5c_row6_col2" class="data row6 col2" >Inpatient</td>
#       <td id="T_81c5c_row6_col3" class="data row6 col3" >PatRev  IC_IP Ancillary services</td>
#       <td id="T_81c5c_row6_col4" class="data row6 col4" >01800</td>
#       <td id="T_81c5c_row6_col5" class="data row6 col5" >3.25</td>
#     </tr>
#     <tr>
#       <th id="T_81c5c_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_81c5c_row7_col0" class="data row7 col0" >Patient Revenues</td>
#       <td id="T_81c5c_row7_col1" class="data row7 col1" >Intensive Care Type Inpatient Hospital Services</td>
#       <td id="T_81c5c_row7_col2" class="data row7 col2" >Outpatient</td>
#       <td id="T_81c5c_row7_col3" class="data row7 col3" >PatRev  IC_IP Ancillary services</td>
#       <td id="T_81c5c_row7_col4" class="data row7 col4" >01800</td>
#       <td id="T_81c5c_row7_col5" class="data row7 col5" >14.96</td>
#     </tr>
#     <tr>
#       <th id="T_81c5c_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_81c5c_row8_col0" class="data row8 col0" >Patient Revenues</td>
#       <td id="T_81c5c_row8_col1" class="data row8 col1" >Intensive Care Type

# %% [markdown]
# ## 4️⃣ Revenue & Expenses Statement

# %%
def get_revenue_expenses(ccn, year):
    """Get revenue & expenses statement for a specific hospital and year"""
    con = duckdb.connect(':memory:')
    
    df = con.execute(f"""
        SELECT
            RE_Report as Report_Section,
            RE_Level as Level,
            RE_Account as Account_Type,
            RE_Line_Name as Account,
            Line as Line_Number,
            Value
        FROM read_parquet('{REVENUE_EXPENSES_PATH}', hive_partitioning=1)
        WHERE Provider_Number = ?
            AND Fiscal_Year = ?
        ORDER BY Line
    """, [int(ccn), int(year)]).df()
    
    con.close()
    
    if df.empty:
        print(f"⚠️ No revenue & expenses data found for CCN {ccn}, Year {year}")
        return None
    
    # Convert to millions
    df['Value ($ Millions)'] = df['Value'].apply(format_millions)
    df = df.drop('Value', axis=1)
    
    return df

# Get and display revenue & expenses
revenue_expenses = get_revenue_expenses(ccn_dropdown.value, year_dropdown.value)

if revenue_expenses is not None:
    print(f"\n📈 Revenue & Expenses Statement")
    print(f"CCN: {ccn_dropdown.value} | Fiscal Year: {year_dropdown.value}")
    print(f"Note: All amounts in millions (USD)")
    print(f"Total records: {len(revenue_expenses):,}\n")
    display(style_dataframe(revenue_expenses))
# Out:
# 📈 Revenue & Expenses Statement
# CCN: 31300 | Fiscal Year: 2024
# Note: All amounts in millions (USD)
# Total records: 12
# <style type="text/css">
# #T_96dca_row0_col0, #T_96dca_row0_col2, #T_96dca_row0_col3, #T_96dca_row0_col4, #T_96dca_row1_col0, #T_96dca_row1_col2, #T_96dca_row1_col3, #T_96dca_row1_col4, #T_96dca_row2_col0, #T_96dca_row2_col2, #T_96dca_row2_col3, #T_96dca_row2_col4, #T_96dca_row3_col0, #T_96dca_row3_col2, #T_96dca_row3_col3, #T_96dca_row3_col4, #T_96dca_row4_col0, #T_96dca_row4_col2, #T_96dca_row4_col3, #T_96dca_row4_col4, #T_96dca_row5_col0, #T_96dca_row5_col2, #T_96dca_row5_col3, #T_96dca_row5_col4, #T_96dca_row6_col0, #T_96dca_row6_col2, #T_96dca_row6_col3, #T_96dca_row6_col4, #T_96dca_row7_col0, #T_96dca_row7_col2, #T_96dca_row7_col3, #T_96dca_row7_col4, #T_96dca_row8_col0, #T_96dca_row8_col2, #T_96dca_row8_col3, #T_96dca_row8_col4, #T_96dca_row9_col0, #T_96dca_row9_col2, #T_96dca_row9_col3, #T_96dca_row9_col4, #T_96dca_row10_col0, #T_96dca_row10_col2, #T_96dca_row10_col3, #T_96dca_row10_col4, #T_96dca_row11_col0, #T_96dca_row11_col2, #T_96dca_row11_col3, #T_96dca_row11_col4 {
#   text-align: left;
# }
# #T_96dca_row0_col1, #T_96dca_row0_col5, #T_96dca_row1_col1, #T_96dca_row1_col5, #T_96dca_row2_col1, #T_96dca_row2_col5, #T_96dca_row3_col1, #T_96dca_row3_col5, #T_96dca_row4_col1, #T_96dca_row4_col5, #T_96dca_row5_col1, #T_96dca_row5_col5, #T_96dca_row6_col1, #T_96dca_row6_col5, #T_96dca_row7_col1, #T_96dca_row7_col5, #T_96dca_row8_col1, #T_96dca_row8_col5, #T_96dca_row9_col1, #T_96dca_row9_col5, #T_96dca_row10_col1, #T_96dca_row10_col5, #T_96dca_row11_col1, #T_96dca_row11_col5 {
#   text-align: right;
# }
# </style>
# <table id="T_96dca">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_96dca_level0_col0" class="col_heading level0 col0" >Report_Section</th>
#       <th id="T_96dca_level0_col1" class="col_heading level0 col1" >Level</th>
#       <th id="T_96dca_level0_col2" class="col_heading level0 col2" >Account_Type</th>
#       <th id="T_96dca_level0_col3" class="col_heading level0 col3" >Account</th>
#       <th id="T_96dca_level0_col4" class="col_heading level0 col4" >Line_Number</th>
#       <th id="T_96dca_level0_col5" class="col_heading level0 col5" >Value ($ Millions)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_96dca_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_96dca_row0_col0" class="data row0 col0" >Revenues and expenses</td>
#       <td id="T_96dca_row0_col1" class="data row0 col1" >1.00</td>
#       <td id="T_96dca_row0_col2" class="data row0 col2" >Total Patient Revenues</td>
#       <td id="T_96dca_row0_col3" class="data row0 col3" >Rev&Exp Total patient revenues</td>
#       <td id="T_96dca_row0_col4" class="data row0 col4" >00100</td>
#       <td id="T_96dca_row0_col5" class="data row0 col5" >153.89</td>
#     </tr>
#     <tr>
#       <th id="T_96dca_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_96dca_row1_col0" class="data row1 col0" >Revenues and expenses</td>
#       <td id="T_96dca_row1_col1" class="data row1 col1" >1.00</td>
#       <td id="T_96dca_row1_col2" class="data row1 col2" >Less Contractual Allowances And Discounts On Patients' Accounts</td>
#       <td id="T_96dca_row1_col3" class="data row1 col3" >Rev&Exp Less contractual allowances and discounts on patients' accounts</td>
#       <td id="T_96dca_row1_col4" class="data row1 col4" >00200</td>
#       <td id="T_96dca_row1_col5" class="data row1 col5" >109.28</td>
#     </tr>
#     <tr>
#       <th id="T_96dca_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_96dca_row2_col0" class="data row2 col0" >Revenues and expenses</td>
#       <td id="T_96dca_row2_col1" class="data row2 col1" >1.00</td>
#       <td id="T_96dca_row2_col2" class="data row2 col2" >Net Patient Revenues</td>
#       <td id="T_96dca_row2_col3" class="data row2 col3" >Rev&Exp Net patient revenues</td>
#       <td id="T_96dca_row2_col4" class="data row2 col4" >00300</td>
#       <td id="T_96dca_row2_col5" class="data row2 col5" >44.61</td>
#     </tr>
#     <tr>
#       <th id="T_96dca_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_96dca_row3_col0" class="data row3 col0" >Revenues and expenses</td>
#       <td id="T_96dca_row3_col1" class="data row3 col1" >1.00</td>
#       <td id="T_96dca_row3_col2" class="data row3 col2" >Less Total Operating Expenses</td>
#       <td id="T_96dca_row3_col3" class="data row3 col3" >Rev&Exp Less total operating expenses</td>
#       <td id="T_96dca_row3_col4" class="data row3 col4" >00400</td>
#       <td id="T_96dca_row3_col5" class="data row3 col5" >51.51</td>
#     </tr>
#     <tr>
#       <th id="T_96dca_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_96dca_row4_col0" class="data row4 col0" >Revenues and expenses</td>
#       <td id="T_96dca_row4_col1" class="data row4 col1" >1.00</td>
#       <td id="T_96dca_row4_col2" class="data row4 col2" >Net Income From Service To Patients</td>
#       <td id="T_96dca_row4_col3" class="data row4 col3" >Rev&Exp Net income from service to patients </td>
#       <td id="T_96dca_row4_col4" class="data row4 col4" >00500</td>
#       <td id="T_96dca_row4_col5" class="data row4 col5" >-6.90</td>
#     </tr>
#     <tr>
#       <th id="T_96dca_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_96dca_row5_col0" class="data row5 col0" >Revenues and expenses</td>
#       <td id="T_96dca_row5_col1" class="data row5 col1" >2.00</td>
#       <td id="T_96dca_row5_col2" class="data row5 col2" >Income From Investments</td>
#       <td id="T_96dca_row5_col3" class="data row5 col3" >Rev&Exp Income from investments</td>
#       <td id="T_96dca_row5_col4" class="data row5 col4" >00700</td>
#       <td id="T_96dca_row5_col5" class="data row5 col5" >0.65</td>
#     </tr>
#     <tr>
#       <th id="T_96dca_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_96dca_row6_col0" class="data row6 col0" >Revenues and expenses</td>
#       <td id="T_96dca_row6_col1" class="data row6 col1" >2.00</td>
#       <td id="T_96dca_row6_col2" class="data row6 col2" >Revenue From Sale Of Medical Records And Abstracts</td>
#       <td id="T_96dca_row6_col3" class="data row6 col3" >Rev&Exp Revenue from sale of medical records and abstracts</td>
#       <td id="T_96dca_row6_col4" class="data row6 col4" >01800</td>
#       <td id="T_96dca_row6_col5" class="data row6 col5" >0.01</td>
#     </tr>
#     <tr>
#       <th id="T_96dca_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_96dca_row7_col0" class="data row7 col0" >Revenues and expenses</td>
#       <td id="T_96dca_row7_col1" class="data row7 col1" >2.00</td>
#       <td id="T_96dca_row7_col2" class="data row7 col2" >Rental Of Hospital Space</td>
#       <td id="T_96dca_row7_col3" class="data row7 col3" >Rev&Exp Rental of hospital space</td>
#       <td id="T_96dca_row7_col4" class="data row7 col4" >02200</td>
#       <td id="T_96dca_row7_col5" class="data row7 col5" >0.09</td>
#     </tr>
#     <tr>
#       <th id="T_96dca_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_96dca_row8_col0" class="data row8 col0" >Revenues and expenses</td>
#       <td id="T_96dca_row8_col1" class="data row8 col1" >3.00</td>
#       <td id="T_96dca_row8_col2" class="data row8 col2" >Other Income</td>
#       <td id="T_96dca_row8_col3" class="data row8 col3" >Rev&Exp Other (specify)</td>
#       <td id="T_96dca_row8_col4" class="data row8 col4" >02400</td>
#       <td id="T_96dca_row8_col5" class="data row8 col5" >7.46</td>
#     </tr>
#     <tr>
#       <th id="T_96dca_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_96dca_row9_col0" class="data row9 col0" >Revenues and expenses</td>
#       <td id="T_96dca_row9_col1" class="data row9 col1" >1.00</td>
#       <td id="T_96dca_row9_col2" class="data row9 col2" >Total Other Income</td>
#       <td id="T_96dca_row9_col3" class="data row9 col3" >Rev&Exp Total other income</td>
#       <td id="T_96dca_row9_col4" class="data row9 col4" >02500</td>
#       <td id="T_96dca_row9_col5" class="data row9 col5" >8.20</td>
#     </tr>
#     <tr>
#       <th id="T_96dca_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id

# %% [markdown]
# ## 5️⃣ Cost Summary (from B100)

# %%
def get_cost_summary(ccn, year):
    """Get cost summary from B100 (total costs by cost center)"""
    con = duckdb.connect(':memory:')
    
    df = con.execute(f"""
        SELECT
            CAST(Line AS INTEGER) as Line_Number,
                     \"Column\", 
            CAST(\"Column\" AS INTEGER) as Column_Number,
            Account_group as Cost_Category,
            Account_name as Cost_Center,
            Value
        FROM read_parquet('{COSTS_B100_PATH}', hive_partitioning=1)
        WHERE Provider_Number = ?
            AND Fiscal_Year = ?
            AND CAST(Line AS INTEGER) >= 3000
            AND CAST(Line AS INTEGER) <= 20200
            --AND CAST(\"Column\" AS INTEGER) = 2600
            AND \"Column\" = '00000'
        ORDER BY CAST(Line AS INTEGER)
    """, [int(ccn), int(year)]).df()
    
    con.close()
    
    if df.empty:
        print(f"⚠️ No cost summary data found for CCN {ccn}, Year {year}")
        return None
    
    # Convert to millions
    df['Value ($ Millions)'] = df['Value'].apply(format_millions)
    df = df.drop('Value', axis=1)
    
    return df

# Get and display cost summary
cost_summary = get_cost_summary(ccn_dropdown.value, year_dropdown.value)

if cost_summary is not None:
    print(f"\n💸 Cost Summary")
    print(f"CCN: {ccn_dropdown.value} | Fiscal Year: {year_dropdown.value}")
    print(f"Note: All amounts in millions (USD)")
    print(f"Total records: {len(cost_summary):,}\n")
    display(style_dataframe(cost_summary))
# Out:
# 💸 Cost Summary
# CCN: 31300 | Fiscal Year: 2024
# Note: All amounts in millions (USD)
# Total records: 72
# <style type="text/css">
# #T_0894f_row0_col0, #T_0894f_row0_col2, #T_0894f_row0_col5, #T_0894f_row1_col0, #T_0894f_row1_col2, #T_0894f_row1_col5, #T_0894f_row2_col0, #T_0894f_row2_col2, #T_0894f_row2_col5, #T_0894f_row3_col0, #T_0894f_row3_col2, #T_0894f_row3_col5, #T_0894f_row4_col0, #T_0894f_row4_col2, #T_0894f_row4_col5, #T_0894f_row5_col0, #T_0894f_row5_col2, #T_0894f_row5_col5, #T_0894f_row6_col0, #T_0894f_row6_col2, #T_0894f_row6_col5, #T_0894f_row7_col0, #T_0894f_row7_col2, #T_0894f_row7_col5, #T_0894f_row8_col0, #T_0894f_row8_col2, #T_0894f_row8_col5, #T_0894f_row9_col0, #T_0894f_row9_col2, #T_0894f_row9_col5, #T_0894f_row10_col0, #T_0894f_row10_col2, #T_0894f_row10_col5, #T_0894f_row11_col0, #T_0894f_row11_col2, #T_0894f_row11_col5, #T_0894f_row12_col0, #T_0894f_row12_col2, #T_0894f_row12_col5, #T_0894f_row13_col0, #T_0894f_row13_col2, #T_0894f_row13_col5, #T_0894f_row14_col0, #T_0894f_row14_col2, #T_0894f_row14_col5, #T_0894f_row15_col0, #T_0894f_row15_col2, #T_0894f_row15_col5, #T_0894f_row16_col0, #T_0894f_row16_col2, #T_0894f_row16_col5, #T_0894f_row17_col0, #T_0894f_row17_col2, #T_0894f_row17_col5, #T_0894f_row18_col0, #T_0894f_row18_col2, #T_0894f_row18_col5, #T_0894f_row19_col0, #T_0894f_row19_col2, #T_0894f_row19_col5, #T_0894f_row20_col0, #T_0894f_row20_col2, #T_0894f_row20_col5, #T_0894f_row21_col0, #T_0894f_row21_col2, #T_0894f_row21_col5, #T_0894f_row22_col0, #T_0894f_row22_col2, #T_0894f_row22_col5, #T_0894f_row23_col0, #T_0894f_row23_col2, #T_0894f_row23_col5, #T_0894f_row24_col0, #T_0894f_row24_col2, #T_0894f_row24_col5, #T_0894f_row25_col0, #T_0894f_row25_col2, #T_0894f_row25_col5, #T_0894f_row26_col0, #T_0894f_row26_col2, #T_0894f_row26_col5, #T_0894f_row27_col0, #T_0894f_row27_col2, #T_0894f_row27_col5, #T_0894f_row28_col0, #T_0894f_row28_col2, #T_0894f_row28_col5, #T_0894f_row29_col0, #T_0894f_row29_col2, #T_0894f_row29_col5, #T_0894f_row30_col0, #T_0894f_row30_col2, #T_0894f_row30_col5, #T_0894f_row31_col0, #T_0894f_row31_col2, #T_0894f_row31_col5, #T_0894f_row32_col0, #T_0894f_row32_col2, #T_0894f_row32_col5, #T_0894f_row33_col0, #T_0894f_row33_col2, #T_0894f_row33_col5, #T_0894f_row34_col0, #T_0894f_row34_col2, #T_0894f_row34_col5, #T_0894f_row35_col0, #T_0894f_row35_col2, #T_0894f_row35_col5, #T_0894f_row36_col0, #T_0894f_row36_col2, #T_0894f_row36_col5, #T_0894f_row37_col0, #T_0894f_row37_col2, #T_0894f_row37_col5, #T_0894f_row38_col0, #T_0894f_row38_col2, #T_0894f_row38_col5, #T_0894f_row39_col0, #T_0894f_row39_col2, #T_0894f_row39_col5, #T_0894f_row40_col0, #T_0894f_row40_col2, #T_0894f_row40_col5, #T_0894f_row41_col0, #T_0894f_row41_col2, #T_0894f_row41_col5, #T_0894f_row42_col0, #T_0894f_row42_col2, #T_0894f_row42_col5, #T_0894f_row43_col0, #T_0894f_row43_col2, #T_0894f_row43_col5, #T_0894f_row44_col0, #T_0894f_row44_col2, #T_0894f_row44_col5, #T_0894f_row45_col0, #T_0894f_row45_col2, #T_0894f_row45_col5, #T_0894f_row46_col0, #T_0894f_row46_col2, #T_0894f_row46_col5, #T_0894f_row47_col0, #T_0894f_row47_col2, #T_0894f_row47_col5, #T_0894f_row48_col0, #T_0894f_row48_col2, #T_0894f_row48_col5, #T_0894f_row49_col0, #T_0894f_row49_col2, #T_0894f_row49_col5, #T_0894f_row50_col0, #T_0894f_row50_col2, #T_0894f_row50_col5, #T_0894f_row51_col0, #T_0894f_row51_col2, #T_0894f_row51_col5, #T_0894f_row52_col0, #T_0894f_row52_col2, #T_0894f_row52_col5, #T_0894f_row53_col0, #T_0894f_row53_col2, #T_0894f_row53_col5, #T_0894f_row54_col0, #T_0894f_row54_col2, #T_0894f_row54_col5, #T_0894f_row55_col0, #T_0894f_row55_col2, #T_0894f_row55_col5, #T_0894f_row56_col0, #T_0894f_row56_col2, #T_0894f_row56_col5, #T_0894f_row57_col0, #T_0894f_row57_col2, #T_0894f_row57_col5, #T_0894f_row58_col0, #T_0894f_row58_col2, #T_0894f_row58_col5, #T_0894f_row59_col0, #T_0894f_row59_col2, #T_0894f_row59_col5, #T_0894f_row60_col0, #T_0894f_row60_col2, #T_0894f_row60_col5, #T_0894f_row61_col0, #T_0894f_row61_col2, #T_0894f_row61_col5, #T_0894f_row62_col0, #T_0894f_row62_col2, #T_0894f_row62_col5, #T_0894f_row63_col0, #T_0894f_row63_col2, #T_0894f_row63_col5 ...
#   text-align: right;
# }
# #T_0894f_row0_col1, #T_0894f_row0_col3, #T_0894f_row0_col4, #T_0894f_row1_col1, #T_0894f_row1_col3, #T_0894f_row1_col4, #T_0894f_row2_col1, #T_0894f_row2_col3, #T_0894f_row2_col4, #T_0894f_row3_col1, #T_0894f_row3_col3, #T_0894f_row3_col4, #T_0894f_row4_col1, #T_0894f_row4_col3, #T_0894f_row4_col4, #T_0894f_row5_col1, #T_0894f_row5_col3, #T_0894f_row5_col4, #T_0894f_row6_col1, #T_0894f_row6_col3, #T_0894f_row6_col4, #T_0894f_row7_col1, #T_0894f_row7_col3, #T_0894f_row7_col4, #T_0894f_row8_col1, #T_0894f_row8_col3, #T_0894f_row8_col4, #T_0894f_row9_col1, #T_0894f_row9_col3, #T_0894f_row9_col4, #T_0894f_row10_col1, #T_0894f_row10_col3, #T_0894f_row10_col4, #T_0894f_row11_col1, #T_0894f_row11_col3, #T_0894f_row11_col4, #T_0894f_row12_col1, #T_0894f_row12_col3, #T_0894f_row12_col4, #T_0894f_row13_col1, #T_0894f_row13_col3, #T_0894f_row13_col4, #T_0894f_row14_col1, #T_0894f_row14_col3, #T_0894f_row14_col4, #T_0894f_row15_col1, #T_0894f_row15_col3, #T_0894f_row15_col4, #T_0894f_row16_col1, #T_0894f_row16_col3, #T_0894f_row16_col4, #T_0894f_row17_col1, #T_0894f_row17_col3, #T_0894f_row17_col4, #T_0894f_row18_col1, #T_0894f_row18_col3, #T_0894f_row18_col4, #T_0894f_row19_col1, #T_0894f_row19_col3, #T_0894f_row19_col4, #T_0894f_row20_col1, #T_0894f_row20_col3, #T_0894f_row20_col4, #T_0894f_row21_col1, #T_0894f_row21_col3, #T_0894f_row21_col4, #T_0894f_row22_col1, #T_0894f_row22_col3, #T_0894f_row22_col4, #T_0894f_row23_col1, #T_0894f_row23_col3, #T_0894f_row23_col4, #T_0894f_row24_col1, #T_0894f_row24_col3, #T_0894f_row24_col4, #T_0894f_row25_col1, #T_0894f_row25_col3, #T_0894f_row25_col4, #T_0894f_row26_col1, #T_0894f_row26_col3, #T_0894f_row26_col4, #T_0894f_row27_col1, #T_0894f_row27_col3, #T_0894f_row27_col4, #T_0894f_row28_col1, #T_0894f_row28_col3, #T_0894f_row28_col4, #T_0894f_row29_col1, #T_0894f_row29_col3, #T_0894f_row29_col4, #T_0894f_row30_col1, #T_0894f_row30_col3, #T_0894f_row30_col4, #T_0894f_row31_col1, #T_0894f_row31_col3, #T_0894f_row31_col4, #T_0894f_row32_col1, #T_0894f_row32_col3, #T_0894f_row32_col4, #T_0894f_row33_col1, #T_0894f_row33_col3, #T_0894f_row33_col4, #T_0894f_row34_col1, #T_0894f_row34_col3, #T_0894f_row34_col4, #T_0894f_row35_col1, #T_0894f_row35_col3, #T_0894f_row35_col4, #T_0894f_row36_col1, #T_0894f_row36_col3, #T_0894f_row36_col4, #T_0894f_row37_col1, #T_0894f_row37_col3, #T_0894f_row37_col4, #T_0894f_row38_col1, #T_0894f_row38_col3, #T_0894f_row38_col4, #T_0894f_row39_col1, #T_0894f_row39_col3, #T_0894f_row39_col4, #T_0894f_row40_col1, #T_0894f_row40_col3, #T_0894f_row40_col4, #T_0894f_row41_col1, #T_0894f_row41_col3, #T_0894f_row41_col4, #T_0894f_row42_col1, #T_0894f_row42_col3, #T_0894f_row42_col4, #T_0894f_row43_col1, #T_0894f_row43_col3, #T_0894f_row43_col4, #T_0894f_row44_col1, #T_0894f_row44_col3, #T_0894f_row44_col4, #T_0894f_row45_col1, #T_0894f_row45_col3, #T_0894f_row45_col4, #T_0894f_row46_col1, #T_0894f_row46_col3, #T_0894f_row46_col4, #T_0894f_row47_col1, #T_0894f_row47_col3, #T_0894f_row47_col4, #T_0894f_row48_col1, #T_0894f_row48_col3, #T_0894f_row48_col4, #T_0894f_row49_col1, #T_0894f_row49_col3, #T_0894f_row49_col4, #T_0894f_row50_col1, #T_0894f_row50_col3, #T_0894f_row50_col4, #T_0894f_row51_col1, #T_0894f_row51_col3, #T_0894f_row51_col4, #T_0894f_row52_col1, #T_0894f_row52_col3, #T_0894f_row52_col4, #T_0894f_row53_col1, #T_0894f_row53_col3, #T_0894f_row53_col4, #T_0894f_row54_col1, #T_0894f_row54_col3, #T_0894f_row54_col4, #T_0894f_ro

# %%
def get_cost_summary(ccn, year):
    """Get cost summary from B100 (total costs by cost center)"""
    con = duckdb.connect(':memory:')
    
    df = con.execute(f"""
        SELECT
            *
        FROM read_parquet('{COSTS_B100_PATH}', hive_partitioning=1)
        WHERE Provider_Number = ?
            AND Fiscal_Year = ?
    """, [int(ccn), int(year)]).df()
    
    con.close()
    
    if df.empty:
        print(f"⚠️ No cost summary data found for CCN {ccn}, Year {year}")
        return None
    
    # Convert to millions
    df['Value ($ Millions)'] = df['Value'].apply(format_millions)
    df = df.drop('Value', axis=1)
    
    return df

# Get and display cost summary
cost_summary = get_cost_summary(ccn_dropdown.value, year_dropdown.value)

cost_summary
# Out:
#       Provider_Number    Year  NPI  Control_Type  Report_Status    FY_Begin  \
# 0            31300.00 2024.00  NaN          2.00           1.00  01/01/2024
# 1            31300.00 2024.00  NaN          2.00           1.00  01/01/2024
# 2            31300.00 2024.00  NaN          2.00           1.00  01/01/2024
# 3            31300.00 2024.00  NaN          2.00           1.00  01/01/2024
# 4            31300.00 2024.00  NaN          2.00           1.00  01/01/2024
# ...               ...     ...  ...           ...            ...         ...
# 1413         31300.00 2024.00  NaN          2.00           1.00  01/01/2024
# 1414         31300.00 2024.00  NaN          2.00           1.00  01/01/2024
# 1415         31300.00 2024.00  NaN          2.00           1.00  01/01/2024
# 1416         31300.00 2024.00  NaN          2.00           1.00  01/01/2024
# 1417         31300.00 2024.00  NaN          2.00           1.00  01/01/2024
#
#          FY_End  Geographic_Code Worksheet   Line Column  \
# 0    2024-12-31          5901.00   B000001  00100  00000
# 1    2024-12-31          5901.00   B000001  00100  00100
# 2    2024-12-31          5901.00   B000001  00200  00000
# 3    2024-12-31          5901.00   B000001  00200  00200
# 4    2024-12-31          5901.00   B000001  00400  00000
# ...         ...              ...       ...    ...    ...
# 1413 2024-12-31          5901.00   B000001  20200  01400
# 1414 2024-12-31          5901.00   B000001  20200  01500
# 1415 2024-12-31          5901.00   B000001  20200  01600
# 1416 2024-12-31          5901.00   B000001  20200  02400
# 1417 2024-12-31          5901.00   B000001  20200  02600
#
#                      Account_group                        Account_name  \
# 0     General Service Cost Centers  New Capital Buildings and Fixtures
# 1                             None                                None
# 2     General Service Cost Centers               New Capital Equipment
# 3                             None                                None
# 4     General Service Cost Centers                   Employee Benefits
# ...                            ...                                 ...
# 1413                          None                                None
# 1414                          None                                None
# 1415                          None                                None
# 1416                          None                                None
# 1417                          None                                None
#
#      Overhead_center Fiscal_Year State_Code  Value ($ Millions)
# 0       Net Expenses        2024         31                1.10
# 1               None        2024         31                1.10
# 2       Net Expenses        2024         31                1.60
# 3               None        2024         31                1.60
# 4       Net Expenses        2024         31                0.46
# ...              ...         ...        ...                 ...
# 1413            None        2024         31                0.34
# 1414            None        2024         31                2.70
# 1415            None        2024         31                1.24
# 1416            None        2024         31               44.60
# 1417            None        2024         31               44.60
#
# [1418 rows x 17 columns]

# %% [markdown]
# ## 6️⃣ Detailed Costs (with Salary, Direct, and Overhead breakdown)

# %%
def get_detailed_costs(ccn, year):
    """Get detailed costs with salary, other direct, and overhead breakdown"""
    con = duckdb.connect(':memory:')
    
    query = f"""
    WITH
    -- Get A000 data and calculate totals
    a000_data AS (
        SELECT
            Provider_Number,
            Fiscal_Year,
            CAST(Line AS INTEGER) as Line,
            Account_name,
            MAX(CASE WHEN \"Column\" = '00100' THEN Value ELSE 0 END) as Col_100,
            MAX(CASE WHEN \"Column\" = '00200' THEN Value ELSE 0 END) as Col_200,
            MAX(CASE WHEN \"Column\" = '00400' THEN Value ELSE 0 END) as Col_400,
            MAX(CASE WHEN \"Column\" = '00600' THEN Value ELSE 0 END) as Col_600
        FROM read_parquet('{COSTS_A000_PATH}', hive_partitioning=1)
        WHERE Provider_Number = ?
          AND Fiscal_Year = ?
          AND CAST(Line AS INTEGER) >= 3000
          AND CAST(Line AS INTEGER) <= 20200
        GROUP BY Provider_Number, Fiscal_Year, CAST(Line AS INTEGER), Account_name
    ),
    a000_calc AS (
        SELECT
            *,
            (Col_100 + Col_200 + Col_400 + Col_600) as Col_700,
            CASE
                WHEN (Col_100 + Col_200) > 0
                THEN (Col_100 + Col_200 + Col_400 + Col_600) * (Col_100 / (Col_100 + Col_200))
                ELSE 0
            END as Salary,
            CASE
                WHEN (Col_100 + Col_200) > 0
                THEN (Col_100 + Col_200 + Col_400 + Col_600) * (Col_200 / (Col_100 + Col_200))
                ELSE 0
            END as Other_Direct
        FROM a000_data
    ),
    -- Get B100 overhead data
    b100_data AS (
        SELECT
            Provider_Number,
            Fiscal_Year,
            CAST(Line AS INTEGER) as Line,
            MAX(CASE WHEN \"Column\" = '00100' THEN Value ELSE 0 END) as OH_Col_100,
            MAX(CASE WHEN \"Column\" = '00200' THEN Value ELSE 0 END) as OH_Col_200,
            MAX(CASE WHEN \"Column\" = '00400' THEN Value ELSE 0 END) as OH_Col_400,
            MAX(CASE WHEN \"Column\" = '00500' THEN Value ELSE 0 END) as OH_Col_500,
            MAX(CASE WHEN \"Column\" = '02600' THEN Value ELSE 0 END) as OH_Col_2600
        FROM read_parquet('{COSTS_B100_PATH}', hive_partitioning=1)
        WHERE Provider_Number = ?
          AND Fiscal_Year = ?
          AND CAST(Line AS INTEGER) >= 3000
          AND CAST(Line AS INTEGER) <= 20200
        GROUP BY Provider_Number, Fiscal_Year, CAST(Line AS INTEGER)
    ),
    b100_calc AS (
        SELECT
            *,
            (OH_Col_100 + OH_Col_200) as Bldg_Equipment,
            OH_Col_400 as Employee_Benefits,
            OH_Col_500 as Admin_General,
            (OH_Col_2600 - OH_Col_100 - OH_Col_200 - OH_Col_400 - OH_Col_500) as Other_Overhead
        FROM b100_data
    )
    -- Join and combine all data
    SELECT
        COALESCE(a.Line, b.Line) as Line_Number,
        a.Account_name as Cost_Center,
        a.Salary,
        a.Other_Direct,
        b.Bldg_Equipment,
        b.Employee_Benefits,
        b.Admin_General,
        b.Other_Overhead,
        (COALESCE(a.Salary, 0) + COALESCE(a.Other_Direct, 0) +
         COALESCE(b.Bldg_Equipment, 0) + COALESCE(b.Employee_Benefits, 0) +
         COALESCE(b.Admin_General, 0) + COALESCE(b.Other_Overhead, 0)) as Total_Cost
    FROM a000_calc a
    FULL OUTER JOIN b100_calc b
        ON a.Provider_Number = b.Provider_Number
        AND a.Fiscal_Year = b.Fiscal_Year
        AND a.Line = b.Line
    ORDER BY Line_Number
    """
    
    df = con.execute(query, [int(ccn), int(year), int(ccn), int(year)]).df()
    
    con.close()
    
    if df.empty:
        print(f"⚠️ No detailed costs data found for CCN {ccn}, Year {year}")
        return None
    
    # Convert all numeric columns to millions
    for col in ['Salary', 'Other_Direct', 'Bldg_Equipment', 'Employee_Benefits', 'Admin_General', 'Other_Overhead', 'Total_Cost']:
        if col in df.columns:
            df[f'{col} ($M)'] = df[col].apply(format_millions)
            df = df.drop(col, axis=1)
    
    return df

# Get and display detailed costs
detailed_costs = get_detailed_costs(ccn_dropdown.value, year_dropdown.value)

if detailed_costs is not None:
    print(f"\n📊 Detailed Costs (with Salary, Direct, and Overhead breakdown)")
    print(f"CCN: {ccn_dropdown.value} | Fiscal Year: {year_dropdown.value}")
    print(f"Note: All amounts in millions (USD)")
    print(f"Total records: {len(detailed_costs):,}\n")
    display(style_dataframe(detailed_costs))
# Out:
# 📊 Detailed Costs (with Salary, Direct, and Overhead breakdown)
# CCN: 31300 | Fiscal Year: 2024
# Note: All amounts in millions (USD)
# Total records: 39
# <style type="text/css">
# #T_f82b6_row0_col0, #T_f82b6_row0_col2, #T_f82b6_row0_col3, #T_f82b6_row0_col4, #T_f82b6_row0_col5, #T_f82b6_row0_col6, #T_f82b6_row0_col7, #T_f82b6_row0_col8, #T_f82b6_row1_col0, #T_f82b6_row1_col2, #T_f82b6_row1_col3, #T_f82b6_row1_col4, #T_f82b6_row1_col5, #T_f82b6_row1_col6, #T_f82b6_row1_col7, #T_f82b6_row1_col8, #T_f82b6_row2_col0, #T_f82b6_row2_col2, #T_f82b6_row2_col3, #T_f82b6_row2_col4, #T_f82b6_row2_col5, #T_f82b6_row2_col6, #T_f82b6_row2_col7, #T_f82b6_row2_col8, #T_f82b6_row3_col0, #T_f82b6_row3_col2, #T_f82b6_row3_col3, #T_f82b6_row3_col4, #T_f82b6_row3_col5, #T_f82b6_row3_col6, #T_f82b6_row3_col7, #T_f82b6_row3_col8, #T_f82b6_row4_col0, #T_f82b6_row4_col2, #T_f82b6_row4_col3, #T_f82b6_row4_col4, #T_f82b6_row4_col5, #T_f82b6_row4_col6, #T_f82b6_row4_col7, #T_f82b6_row4_col8, #T_f82b6_row5_col0, #T_f82b6_row5_col2, #T_f82b6_row5_col3, #T_f82b6_row5_col4, #T_f82b6_row5_col5, #T_f82b6_row5_col6, #T_f82b6_row5_col7, #T_f82b6_row5_col8, #T_f82b6_row6_col0, #T_f82b6_row6_col2, #T_f82b6_row6_col3, #T_f82b6_row6_col4, #T_f82b6_row6_col5, #T_f82b6_row6_col6, #T_f82b6_row6_col7, #T_f82b6_row6_col8, #T_f82b6_row7_col0, #T_f82b6_row7_col2, #T_f82b6_row7_col3, #T_f82b6_row7_col4, #T_f82b6_row7_col5, #T_f82b6_row7_col6, #T_f82b6_row7_col7, #T_f82b6_row7_col8, #T_f82b6_row8_col0, #T_f82b6_row8_col2, #T_f82b6_row8_col3, #T_f82b6_row8_col4, #T_f82b6_row8_col5, #T_f82b6_row8_col6, #T_f82b6_row8_col7, #T_f82b6_row8_col8, #T_f82b6_row9_col0, #T_f82b6_row9_col2, #T_f82b6_row9_col3, #T_f82b6_row9_col4, #T_f82b6_row9_col5, #T_f82b6_row9_col6, #T_f82b6_row9_col7, #T_f82b6_row9_col8, #T_f82b6_row10_col0, #T_f82b6_row10_col2, #T_f82b6_row10_col3, #T_f82b6_row10_col4, #T_f82b6_row10_col5, #T_f82b6_row10_col6, #T_f82b6_row10_col7, #T_f82b6_row10_col8, #T_f82b6_row11_col0, #T_f82b6_row11_col2, #T_f82b6_row11_col3, #T_f82b6_row11_col4, #T_f82b6_row11_col5, #T_f82b6_row11_col6, #T_f82b6_row11_col7, #T_f82b6_row11_col8, #T_f82b6_row12_col0, #T_f82b6_row12_col2, #T_f82b6_row12_col3, #T_f82b6_row12_col4, #T_f82b6_row12_col5, #T_f82b6_row12_col6, #T_f82b6_row12_col7, #T_f82b6_row12_col8, #T_f82b6_row13_col0, #T_f82b6_row13_col2, #T_f82b6_row13_col3, #T_f82b6_row13_col4, #T_f82b6_row13_col5, #T_f82b6_row13_col6, #T_f82b6_row13_col7, #T_f82b6_row13_col8, #T_f82b6_row14_col0, #T_f82b6_row14_col2, #T_f82b6_row14_col3, #T_f82b6_row14_col4, #T_f82b6_row14_col5, #T_f82b6_row14_col6, #T_f82b6_row14_col7, #T_f82b6_row14_col8, #T_f82b6_row15_col0, #T_f82b6_row15_col2, #T_f82b6_row15_col3, #T_f82b6_row15_col4, #T_f82b6_row15_col5, #T_f82b6_row15_col6, #T_f82b6_row15_col7, #T_f82b6_row15_col8, #T_f82b6_row16_col0, #T_f82b6_row16_col2, #T_f82b6_row16_col3, #T_f82b6_row16_col4, #T_f82b6_row16_col5, #T_f82b6_row16_col6, #T_f82b6_row16_col7, #T_f82b6_row16_col8, #T_f82b6_row17_col0, #T_f82b6_row17_col2, #T_f82b6_row17_col3, #T_f82b6_row17_col4, #T_f82b6_row17_col5, #T_f82b6_row17_col6, #T_f82b6_row17_col7, #T_f82b6_row17_col8, #T_f82b6_row18_col0, #T_f82b6_row18_col2, #T_f82b6_row18_col3, #T_f82b6_row18_col4, #T_f82b6_row18_col5, #T_f82b6_row18_col6, #T_f82b6_row18_col7, #T_f82b6_row18_col8, #T_f82b6_row19_col0, #T_f82b6_row19_col2, #T_f82b6_row19_col3, #T_f82b6_row19_col4, #T_f82b6_row19_col5, #T_f82b6_row19_col6, #T_f82b6_row19_col7, #T_f82b6_row19_col8, #T_f82b6_row20_col0, #T_f82b6_row20_col2, #T_f82b6_row20_col3, #T_f82b6_row20_col4, #T_f82b6_row20_col5, #T_f82b6_row20_col6, #T_f82b6_row20_col7, #T_f82b6_row20_col8, #T_f82b6_row21_col0, #T_f82b6_row21_col2, #T_f82b6_row21_col3, #T_f82b6_row21_col4, #T_f82b6_row21_col5, #T_f82b6_row21_col6, #T_f82b6_row21_col7, #T_f82b6_row21_col8, #T_f82b6_row22_col0, #T_f82b6_row22_col2, #T_f82b6_row22_col3, #T_f82b6_row22_col4, #T_f82b6_row22_col5, #T_f82b6_row22_col6, #T_f82b6_row22_col7, #T_f82b6_row22_col8, #T_f82b6_row23_col0, #T_f82b6_row23_col2, #T_f82b6_row23_col3, #T_f82b6_row23_col4, #T_f82b6_row23_col5, #T_f82b6_row23_col6, #T_f82b6_row23_col7, #T_f82b6_row23_col8, #T_f82b6_row24_col0, #T_f82b6_row24_col2, #T_f82 ...
#   text-align: right;
# }
# #T_f82b6_row0_col1, #T_f82b6_row1_col1, #T_f82b6_row2_col1, #T_f82b6_row3_col1, #T_f82b6_row4_col1, #T_f82b6_row5_col1, #T_f82b6_row6_col1, #T_f82b6_row7_col1, #T_f82b6_row8_col1, #T_f82b6_row9_col1, #T_f82b6_row10_col1, #T_f82b6_row11_col1, #T_f82b6_row12_col1, #T_f82b6_row13_col1, #T_f82b6_row14_col1, #T_f82b6_row15_col1, #T_f82b6_row16_col1, #T_f82b6_row17_col1, #T_f82b6_row18_col1, #T_f82b6_row19_col1, #T_f82b6_row20_col1, #T_f82b6_row21_col1, #T_f82b6_row22_col1, #T_f82b6_row23_col1, #T_f82b6_row24_col1, #T_f82b6_row25_col1, #T_f82b6_row26_col1, #T_f82b6_row27_col1, #T_f82b6_row28_col1, #T_f82b6_row29_col1, #T_f82b6_row30_col1, #T_f82b6_row31_col1, #T_f82b6_row32_col1, #T_f82b6_row33_col1, #T_f82b6_row34_col1, #T_f82b6_row35_col1, #T_f82b6_row36_col1, #T_f82b6_row37_col1, #T_f82b6_row38_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_f82b6">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_f82b6_level0_col0" class="col_heading level0 col0" >Line_Number</th>
#       <th id="T_f82b6_level0_col1" class="col_heading level0 col1" >Cost_Center</th>
#       <th id="T_f82b6_level0_col2" class="col_heading level0 col2" >Salary ($M)</th>
#       <th id="T_f82b6_level0_col3" class="col_heading level0 col3" >Other_Direct ($M)</th>
#       <th id="T_f82b6_level0_col4" class="col_heading level0 col4" >Bldg_Equipment ($M)</th>
#       <th id="T_f82b6_level0_col5" class="col_heading level0 col5" >Employee_Benefits ($M)</th>
#       <th id="T_f82b

# %% [markdown]
# ## 7️⃣ Export to Excel (Optional)

# %%
def export_to_excel(ccn, year, fund_type='General Fund'):
    """Export all financial reports to Excel file"""
    filename = f"Financial_Reports_CCN{ccn}_FY{year}_Parquet.xlsx"
    
    with pd.ExcelWriter(filename, engine='openpyxl') as writer:
        # Balance Sheet
        bs = get_balance_sheet(ccn, year, fund_type)
        if bs is not None:
            bs.to_excel(writer, sheet_name='Balance Sheet', index=False)
        
        # Fund Balance Changes
        fbc = get_fund_balance_changes(ccn, year)
        if fbc is not None:
            fbc.to_excel(writer, sheet_name='Fund Balance Changes', index=False)
        
        # Revenue
        rev = get_revenue(ccn, year)
        if rev is not None:
            rev.to_excel(writer, sheet_name='Revenue', index=False)
        
        # Revenue & Expenses
        re = get_revenue_expenses(ccn, year)
        if re is not None:
            re.to_excel(writer, sheet_name='Revenue & Expenses', index=False)
        
        # Cost Summary
        cs = get_cost_summary(ccn, year)
        if cs is not None:
            cs.to_excel(writer, sheet_name='Cost Summary', index=False)
        
        # Detailed Costs
        dc = get_detailed_costs(ccn, year)
        if dc is not None:
            dc.to_excel(writer, sheet_name='Detailed Costs', index=False)
    
    print(f"✓ Exported to {filename}")
    return filename

# Uncomment to export:
# export_to_excel(ccn_dropdown.value, year_dropdown.value, fund_dropdown.value)
